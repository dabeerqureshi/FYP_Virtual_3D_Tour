# %%
# STEP 1: Clone the repo and install required packages
# %cd /kaggle/working
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# !pip install -q plyfile

# %cd /kaggle/working/gaussian-splatting
# !pip install -q ./submodules/diff-gaussian-rasterization
# !pip install -q ./submodules/simple-knn
# Out:
# /kaggle/working
# fatal: destination path 'gaussian-splatting' already exists and is not an empty directory.
# /kaggle/working/gaussian-splatting
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for simple_knn

# %%
# Create required structure
# !mkdir -p /kaggle/working/input/images
# !mkdir -p /kaggle/working/input/sparse/0

# Copy images
# !cp /kaggle/input/images11/* /kaggle/working/input/images/

# Copy sparse data
# !cp /kaggle/input/sparse11/* /kaggle/working/input/sparse/0/

# %%
#!python train.py -s /kaggle/working/input
# !python train.py -s /kaggle/working/input --iterations 7000
# Out:
# 2025-04-12 16:59:18.587696: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-12 16:59:18.898021: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-12 16:59:18.989087: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Optimizing
# Output folder: ./output/6ce2262a-7 [12/04 16:59:30]
# Reading camera 28/28 [12/04 16:59:30]
# Converting point3d.bin to .ply, will happen only the first time you open the scene. [12/04 16:59:30]
# Loading Training Cameras [12/04 16:59:30]
# [ INFO ] Encountered quite large input images (>1.6K pixels width), rescaling to 1.6K.
# ...

# %%
import shutil

# Source: Update this path if your output folder has a different name
src = "/kaggle/working/gaussian-splatting/output/6ce2262a-7/point_cloud/iteration_7000/point_cloud.ply"

# Destination: Kaggle allows download from the working directory
dst = "/kaggle/working/point_cloud_7000.ply"

# Copy the file
shutil.copyfile(src, dst)
# Out:
# '/kaggle/working/point_cloud_7000.ply'

# %%
import zipfile

# Define paths
ply_path = '/kaggle/working/point_cloud_7000.ply'
zip_path = '/kaggle/working/point_cloud_7000.zip'

# Create zip
with zipfile.ZipFile(zip_path, 'w') as zipf:
    zipf.write(ply_path, arcname='point_cloud_7000.ply')

print(f"Zipped file created at: {zip_path}")
# Out:
# Zipped file created at: /kaggle/working/point_cloud_7000.zip

# %%
from IPython.display import FileLink

# Ensure the file path is correct
file_path = '/kaggle/working/point_cloud_7000.ply'

# Display download link
FileLink(file_path)
# Out:
# /kaggle/working/point_cloud_7000.ply

# %%
import os

file_path = '/kaggle/working/point_cloud_7000.ply'  # replace with your file path
size_bytes = os.path.getsize(file_path)
size_mb = size_bytes / (1024 * 1024)

print(f"File size: {size_mb:.2f} MB")
# Out:
# File size: 912.76 MB

# %%
print("Hello")
# Out:
# Hello
